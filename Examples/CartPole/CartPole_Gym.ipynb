# %%
import gym
import random

# %% [markdown]
# <p> A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The system is controlled by applying a force of +1 or -1 to the cart. The pendulum starts upright, and the goal is to prevent it from falling over. A reward of +1 is provided for every timestep that the pole remains upright. The episode ends when the pole is more than 15 degrees from vertical, or the cart moves more than 2.4 units from the center. </p>

# %%
env_name = 'CartPole-v0'
env = gym.make(env_name) #define the environment

# %% [markdown]
# <p>The environment is an 4-dimensional box, so valid observations will be an array of 4 numbers.We can check the Box’s bounds below. There are two actions, one of the actions applies force to the left, and one of them applies force to the right. </p>

# %%
print(env.observation_space.high)
print(env.observation_space.low)
print ("Observation Space: ", env.observation_space) #representing your observation of the environment. 
print("Action Space: ",env.action_space) #the number of actions the environment can take
# Out:
# [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]
# [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]
# Observation Space:  Box(4,)
# Action Space:  Discrete(2)

# %% [markdown]
# <p> Choose the action to take based on the pole angle </p>

# %%
class Agent():
    def __init__(self, env):
        self.action_size = env.action_space.n
        print("Action Size: ", self.action_size)
        
    def get_action(self):
        pole_angle = state[2]
        action = 0 if pole_angle < 0 else 1
        return action

# %% [markdown]
# <p>This is an implementation of the classic “agent-environment loop”. Each timestep, the agent chooses an action, and the environment returns an observation and a reward. </p> <a>http://gym.openai.com/docs/#getting-started-with-gym </a>

# %%
agent = Agent(env)
for i_episode in range(20):
    state = env.reset() #The process gets started by calling reset(), which returns an initial observation. 
    for t in range(200):
        env.render()
        #print(state)
        #action = env.action_space.sample()
        action = Agent.get_action(state)
        state, reward, done, info = env.step(action)
        print(state, reward, done, info)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# Action Size:  2
# [-0.00766252 -0.19718325 -0.04928226  0.28893781] 1.0 False {}
# [-0.01160618 -0.39156906 -0.04350351  0.5656794 ] 1.0 False {}
# [-0.01943756 -0.58605456 -0.03218992  0.84434563] 1.0 False {}
# [-0.03115865 -0.78072281 -0.01530301  1.12673453] 1.0 False {}
# [-0.04677311 -0.97564094  0.00723168  1.41457859] 1.0 False {}
# [-0.06628593 -0.78060933  0.03552326  1.12416491] 1.0 False {}
# [-0.08189812 -0.58597058  0.05800655  0.84283262] 1.0 False {}
# [-0.09361753 -0.39168626  0.07486321  0.56894067] 1.0 False {}
# [-0.10145125 -0.19768974  0.08624202  0.30075017] 1.0 False {}
# [-0.10540505 -0.00389611  0.09225702  0.03646382] 1.0 False {}
# [-0.10548297  0.18979008  0.0929863  -0.22574483] 1.0 False {}
# [-0.10168717  0.38346858  0.0884714  -0.48770892] 1.0 False {}
# [-0.0940178   0.57723815  0.07871722 -0.75124984] 1.0 False {}
# [-0.08247303  0.77119138  0.06369223 -1.01815982] 1.0 False {}
# [-0.06704921  0.96540916  0.04332903 -1.29018292] 1.0 False {}
# ...
